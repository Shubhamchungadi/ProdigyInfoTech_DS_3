# %% [markdown]
# ## Business Problem Understanding
#
# ##### Import  Necessary Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## Data Understanding

# %%
data = pd.read_csv(r"D:\Data Science and AI\PYTHON\Prodigy Infotech\Prodigy task 3\bank+marketing\bank\bank-full.csv")
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# #### Understanding the perpose of each columns

# %%
data["age"].unique()             # Age in years
# Out:
# array([58, 44, 33, 47, 35, 28, 42, 43, 41, 29, 53, 57, 51, 45, 60, 56, 32,
#        25, 40, 39, 52, 46, 36, 49, 59, 37, 50, 54, 55, 48, 24, 38, 31, 30,
#        27, 34, 23, 26, 61, 22, 21, 20, 66, 62, 83, 75, 67, 70, 65, 68, 64,
#        69, 72, 71, 19, 76, 85, 63, 90, 82, 73, 74, 78, 80, 94, 79, 77, 86,
#        95, 81, 18, 89, 84, 87, 92, 93, 88])

# %%
data["age"].value_counts()
# Out:
# age
# 32    2085
# 31    1996
# 33    1972
# 34    1930
# 35    1894
#       ...
# 95       2
# 93       2
# 92       2
# 88       2
# 94       1
# Name: count, Length: 77, dtype: int64

# %%
data['job'].unique()                # occuation - type of job
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
data["job"].value_counts()
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64

# %%
data["marital"].unique()                    # Marital Status
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
data["marital"].value_counts()
# Out:
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64

# %%
data["education"].unique()                   # Education Level
# Out:
# array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object)

# %%
data["education"].value_counts()
# Out:
# education
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: count, dtype: int64

# %%
data["default"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data["default"].value_counts()
# Out:
# default
# no     44396
# yes      815
# Name: count, dtype: int64

# %%
data["balance"].unique()                   # average yearly balance
# Out:
# array([ 2143,    29,     2, ...,  8205, 14204, 16353])

# %%
data["balance"].value_counts()
# Out:
# balance
# 0        3514
# 1         195
# 2         156
# 4         139
# 3         134
#          ...
# 14204       1
# 8205        1
# 9710        1
# 7038        1
# 4416        1
# Name: count, Length: 7168, dtype: int64

# %%
data["housing"].unique()             # has housing loan?
# Out:
# array(['yes', 'no'], dtype=object)

# %%
data["housing"].value_counts()
# Out:
# housing
# yes    25130
# no     20081
# Name: count, dtype: int64

# %%
data["loan"].unique()               # has any personal loan
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data["loan"].value_counts()
# Out:
# loan
# no     37967
# yes     7244
# Name: count, dtype: int64

# %%
data["contact"].unique()                 # contact communication type
# Out:
# array(['unknown', 'cellular', 'telephone'], dtype=object)

# %%
data["contact"].value_counts()
# Out:
# contact
# cellular     29285
# unknown      13020
# telephone     2906
# Name: count, dtype: int64

# %%
data["day"].unique()                   # last contact day of the week
# Out:
# array([ 5,  6,  7,  8,  9, 12, 13, 14, 15, 16, 19, 20, 21, 23, 26, 27, 28,
#        29, 30,  2,  3,  4, 11, 17, 18, 24, 25,  1, 10, 22, 31])

# %%
data["day"].value_counts()
# Out:
# day
# 20    2752
# 18    2308
# 21    2026
# 17    1939
# 6     1932
# 5     1910
# 14    1848
# 8     1842
# 28    1830
# 7     1817
# 19    1757
# 29    1745
# 15    1703
# 12    1603
# 13    1585
# 30    1566
# 9     1561
# 11    1479
# 4     1445
# 16    1415
# 2     1293
# 27    1121
# 3     1079
# 26    1035
# 23     939
# 22     905
# 25     840
# 31     643
# 10     524
# 24     447
# 1      322
# Name: count, dtype: int64

# %%
data["month"].unique()              # last contact month of year
# Out:
# array(['may', 'jun', 'jul', 'aug', 'oct', 'nov', 'dec', 'jan', 'feb',
#        'mar', 'apr', 'sep'], dtype=object)

# %%
data["month"].value_counts()
# Out:
# month
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: count, dtype: int64

# %%
data["duration"].unique()                      # last contact duration, in second
# Out:
# array([ 261,  151,   76, ..., 1298, 1246, 1556])

# %%
data["duration"].value_counts()
# Out:
# duration
# 124     188
# 90      184
# 89      177
# 104     175
# 114     175
#        ...
# 1286      1
# 1380      1
# 1723      1
# 2184      1
# 1233      1
# Name: count, Length: 1573, dtype: int64

# %%
# number of contacts performed during this campaign and for this client (numeric, includes last contact)

data["campaign"].unique()
# Out:
# array([ 1,  2,  3,  5,  4,  6,  7,  8,  9, 10, 11, 12, 13, 19, 14, 24, 16,
#        32, 18, 22, 15, 17, 25, 21, 43, 51, 63, 41, 26, 28, 55, 50, 38, 23,
#        20, 29, 31, 37, 30, 46, 27, 58, 33, 35, 34, 36, 39, 44])

# %%
data["campaign"].value_counts()
# Out:
# campaign
# 1     17544
# 2     12505
# 3      5521
# 4      3522
# 5      1764
# 6      1291
# 7       735
# 8       540
# 9       327
# 10      266
# 11      201
# 12      155
# 13      133
# 14       93
# 15       84
# 16       79
# 17       69
# 18       51
# 19       44
# 20       43
# 21       35
# 22       23
# 23       22
# 25       22
# 24       20
# 29       16
# 28       16
# 26       13
# 31       12
# 27       10
# 32        9
# 30        8
# 33        6
# 34        5
# 36        4
# 35        4
# 38        3
# 43        3
# 41        2
# 50        2
# 37        2
# 55        1
# 51        1
# 63        1
# 46        1
# 58        1
# 39        1
# 44        1
# Name: count, dtype: int64

# %%
# number of days that passed by after the client was last contacted from a previous campaign 
# (numeric; -1 means client was not previously contacted)

data["pdays"].unique()
# Out:
# array([ -1, 151, 166,  91,  86, 143, 147,  89, 140, 176, 101, 174, 170,
#        167, 195, 165, 129, 188, 196, 172, 118, 119, 104, 171, 117, 164,
#        132, 131, 123, 159, 186, 111, 115, 116, 173, 178, 110, 152,  96,
#        103, 150, 175, 193, 181, 185, 154, 145, 138, 126, 180, 109, 158,
#        168,  97, 182, 127, 130, 194, 125, 105, 102,  26, 179,  28, 183,
#        155, 112, 120, 137, 124, 187, 190, 113, 162, 134, 169, 189,   8,
#        144, 191, 184, 177,   5,  99, 133,  93,  92,  10, 100, 156, 198,
#        106, 153, 146, 128,   7, 121, 160, 107,  90,  27, 197, 136, 139,
#        122, 157, 149, 135,  30, 114,  98, 192, 163,  34,  95, 141,  31,
#        199,  94, 108,  29, 268, 247, 253, 226, 244, 239, 245, 204, 231,
#        238, 258, 230, 254, 265,  71, 223, 246, 250, 266, 240, 205, 261,
#        259, 241, 260, 234, 251, 225, 161, 237, 262, 248, 255, 220, 227,
#        206, 224, 249, 235, 228, 263,   2, 270, 232, 252, 207, 200, 269,
# ...

# %%
# number of contacts performed before this campaign and for this client

data["previous"].unique()
# Out:
# array([  0,   3,   1,   4,   2,  11,  16,   6,   5,  10,  12,   7,  18,
#          9,  21,   8,  14,  15,  26,  37,  13,  25,  20,  27,  17,  23,
#         38,  29,  24,  51, 275,  22,  19,  30,  58,  28,  32,  40,  55,
#         35,  41])

# %%
data["previous"].value_counts()
# Out:
# previous
# 0      36954
# 1       2772
# 2       2106
# 3       1142
# 4        714
# 5        459
# 6        277
# 7        205
# 8        129
# 9         92
# 10        67
# 11        65
# 12        44
# 13        38
# 15        20
# 14        19
# 17        15
# 16        13
# 19        11
# 23         8
# 20         8
# 18         6
# 22         6
# 24         5
# 27         5
# 29         4
# 21         4
# 25         4
# 30         3
# 26         2
# 37         2
# 28         2
# 38         2
# 51         1
# 275        1
# 58         1
# 32         1
# 40         1
# 55         1
# 35         1
# 41         1
# Name: count, dtype: int64

# %%
# outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')

data["poutcome"].unique()
# Out:
# array(['unknown', 'failure', 'other', 'success'], dtype=object)

# %%
data["poutcome"].value_counts()
# Out:
# poutcome
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: count, dtype: int64

# %%
# has the client subscribed a term deposit?

data["y"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data["y"].value_counts()
# Out:
# y
# no     39922
# yes     5289
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
data.shape
# Out:
# (45211, 17)

# %%
data.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %% [markdown]
# ## Data Distribution
#
# * Categorical Data
# * Discrite Count Data
# * Countinuous Data
#
#
# #### Categorical Data

# %%
cat_col = data.select_dtypes(include="object").columns
Categorical = cat_col

print("Categorical_variables :",Categorical)
# Out:
# Categorical_variables : Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
data[Categorical].head()
# Out:
#             job  marital  education default housing loan  contact month  \
# 0    management  married   tertiary      no     yes   no  unknown   may
# 1    technician   single  secondary      no     yes   no  unknown   may
# 2  entrepreneur  married  secondary      no     yes  yes  unknown   may
# 3   blue-collar  married    unknown      no     yes   no  unknown   may
# 4       unknown   single    unknown      no      no   no  unknown   may
#
#   poutcome   y
# 0  unknown  no
# 1  unknown  no
# 2  unknown  no
# 3  unknown  no
# 4  unknown  no

# %% [markdown]
# #### For Numeric Columns

# %%
num_col = data.select_dtypes(exclude="object").columns
Numeric = num_col

print("Numerical_variables :",Numeric)
# Out:
# Numerical_variables : Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
data[Numeric].dtypes
# Out:
# age         int64
# balance     int64
# day         int64
# duration    int64
# campaign    int64
# pdays       int64
# previous    int64
# dtype: object

# %% [markdown]
# #### Discrete Count

# %%
Discrete_count = ["duration","campaign","pdays","previous","day"]
data[Discrete_count].head()
# Out:
#    duration  campaign  pdays  previous  day
# 0       261         1     -1         0    5
# 1       151         1     -1         0    5
# 2        76         1     -1         0    5
# 3        92         1     -1         0    5
# 4       198         1     -1         0    5

# %% [markdown]
# #### Countinuous

# %%
Countinuous  =  ["age","balance"]
data[Countinuous].head()
# Out:
#    age  balance
# 0   58     2143
# 1   44       29
# 2   33        2
# 3   47     1506
# 4   33        1

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# #####  For Numeric Columns / Countinuous Variables

# %%
data.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# #### Draw a Histogram

# %%
plt.rcParams['figure.figsize']=(18,8)

plt.subplot(1,2,1)
sns.histplot(x="age",data=data,kde=True)

plt.subplot(1,2,2)
sns.histplot(x="balance",data=data,kde=True)

plt.suptitle("Univariate or Numerical Columns")
plt.show()

# %%
data[Countinuous].skew()
# Out:
# age        0.684818
# balance    8.360308
# dtype: float64

# %% [markdown]
# #### Draw a Pairplot

# %%
sns.pairplot(data[Countinuous])
plt.show()

# %% [markdown]
# #### Draw a Heatmap for correlation check

# %%
sns.heatmap(data[Countinuous].corr(),annot=True)
plt.show()

# %%
data[Countinuous].corr()
# Out:
#               age   balance
# age      1.000000  0.097783
# balance  0.097783  1.000000

# %% [markdown]
# #### Draw a Boxplot for Outliers Checking

# %%
# lets the visualize the using box plot

plt.rcParams['figure.figsize']=(18,15)

plt.subplot(2,2,1)
sns.boxplot(data["age"])

plt.subplot(2,2,2)
sns.boxplot(data["balance"])

plt.suptitle("Outliers in the data")
plt.show()

# %% [markdown]
# #### For Discrete Count Varaibles

# %%
data[Discrete_count].describe()
# Out:
#            duration      campaign         pdays      previous           day
# count  45211.000000  45211.000000  45211.000000  45211.000000  45211.000000
# mean     258.163080      2.763841     40.197828      0.580323     15.806419
# std      257.527812      3.098021    100.128746      2.303441      8.322476
# min        0.000000      1.000000     -1.000000      0.000000      1.000000
# 25%      103.000000      1.000000     -1.000000      0.000000      8.000000
# 50%      180.000000      2.000000     -1.000000      0.000000     16.000000
# 75%      319.000000      3.000000     -1.000000      0.000000     21.000000
# max     4918.000000     63.000000    871.000000    275.000000     31.000000

# %%
data[Discrete_count].corr()
# Out:
#           duration  campaign     pdays  previous       day
# duration  1.000000 -0.084570 -0.001565  0.001203 -0.030206
# campaign -0.084570  1.000000 -0.088628 -0.032855  0.162490
# pdays    -0.001565 -0.088628  1.000000  0.454820 -0.093044
# previous  0.001203 -0.032855  0.454820  1.000000 -0.051710
# day      -0.030206  0.162490 -0.093044 -0.051710  1.000000

# %% [markdown]
# ### For Discrete Categorical

# %%
data[Categorical].describe()
# Out:
#                 job  marital  education default housing   loan   contact  \
# count         45211    45211      45211   45211   45211  45211     45211
# unique           12        3          4       2       2      2         3
# top     blue-collar  married  secondary      no     yes     no  cellular
# freq           9732    27214      23202   44396   25130  37967     29285
#
#         month poutcome      y
# count   45211    45211  45211
# unique     12        4      2
# top       may  unknown     no
# freq    13766    36959  39922

# %% [markdown]
# #### Draw a Countplot

# %%
# Calculate number of rows and columns for subplots
num_plots = len(Categorical)
num_rows = (num_plots + 1) // 2  # Round up if number of plots is odd
num_cols = 2  # Number of columns in the subplot grid

# Create a figure with a specific size
plt.figure(figsize=(12,20))

# Loop through each column and create a countplot
for i, feature in enumerate(data[Categorical], 1):
    plt.subplot(num_rows, num_cols, i)  # Create subplot
    sns.countplot(x=feature, data=data,hue=feature)
    plt.title(f'Countplot of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.xticks(rotation = 45)

# Adjust layout to prevent overlapping subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Job Distribution based on Education

# %%
plt.figure(figsize=(18,8))
sns.countplot(x="job",data=data,hue="education")
plt.title("Job Distribution based on Education")
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.countplot(x="education",data=data,hue="job")
plt.title("Job Distribution based on Education")
plt.show()

# %% [markdown]
# ### Personal Loan Distribution based on Marital Status

# %%
plt.figure(figsize=(18,8))
sns.countplot(x="loan",data=data,hue="marital")
plt.title("Loan Distribution based on Marital Status")
plt.show()

# %% [markdown]
# ### Housing loan Distribution based on Marital Status

# %%
plt.figure(figsize=(18,8))
sns.countplot(x="housing",data=data,hue="marital")
plt.title("Housing loan Distribution based on Marital Status")
plt.show()

# %% [markdown]
# ### How many people with Jobs are Married ?

# %%
plt.figure(figsize=(18,8))
sns.countplot(x="job",data=data,hue="marital")
plt.title("Job Distribution based on Marital Status")
plt.show()

# %% [markdown]
# ### Job Distribution based on Housing Loan

# %%
plt.figure(figsize=(18,8))
sns.countplot(x ="job",data=data,hue="housing")
plt.title("Job Distribution based on Housing Loan")
plt.show()

# %% [markdown]
# ### Job Distribution based on Personal Loan

# %%
plt.figure(figsize=(18,8))
sns.countplot(x="job",data=data,hue="loan")
plt.title("Job Distribution based on Personal Loan")
plt.show()

# %% [markdown]
# ### Marital Stutas with Percentage

# %%
plt.figure(figsize=(18,8))
plt.pie(x = data["marital"].value_counts(),labels = data["marital"].unique(),autopct='%1.1f%%',startangle =140)
plt.title("Marital Stutas with Percentage")
plt.show()

# %% [markdown]
# ###  Missing Values Check

# %%
data.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# ### Check data type
# ##### Categorical Variables

# %%
print(data[Categorical].dtypes)
# Out:
# job          object
# marital      object
# education    object
# default      object
# housing      object
# loan         object
# contact      object
# month        object
# poutcome     object
# y            object
# dtype: object

# %% [markdown]
# ##### Countinuous Variables

# %%
print(data[Countinuous].dtypes)
# Out:
# age        int64
# balance    int64
# dtype: object

# %% [markdown]
# ##### Discrete Count Variables

# %%
print(data[Discrete_count].dtypes)
# Out:
# duration    int64
# campaign    int64
# pdays       int64
# previous    int64
# day         int64
# dtype: object

# %% [markdown]
# ### Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data["job"]        = le.fit_transform(data["job"])
data["marital"]    = le.fit_transform(data["marital"])
data["education"]  = le.fit_transform(data["education"])
data["default"]    = le.fit_transform(data["default"])
data["housing"]    = le.fit_transform(data["housing"])
data["loan"]       = le.fit_transform(data["loan"])
data["contact"]    = le.fit_transform(data["contact"])
data["month"]      = le.fit_transform(data["month"])
data["poutcome"]   = le.fit_transform(data["poutcome"])
data["y"]          = le.fit_transform(data["y"])

# %%
data.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0    5      8       261         1     -1         0         3  0
# 1    5      8       151         1     -1         0         3  0
# 2    5      8        76         1     -1         0         3  0
# 3    5      8        92         1     -1         0         3  0
# 4    5      8       198         1     -1         0         3  0

# %% [markdown]
# ### Transformation
#
# * Always skewness value lies between -1 to +1

# %%
data[Countinuous].skew()
# Out:
# age        0.684818
# balance    8.360308
# dtype: float64

# %%
data["balance"] = data["balance"]**(1/4)          # Applying Root Transformation

# %%
data[Countinuous].skew()
# Out:
# age        0.684818
# balance    0.045532
# dtype: float64

# %%
data.isnull().sum()
# Out:
# age             0
# job             0
# marital         0
# education       0
# default         0
# balance      3766
# housing         0
# loan            0
# contact         0
# day             0
# month           0
# duration        0
# campaign        0
# pdays           0
# previous        0
# poutcome        0
# y               0
# dtype: int64

# %% [markdown]
# #### Countinuous variables null value replace with mean

# %%
data["balance"].fillna(data["balance"].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
data["balance"].skew()
# Out:
# np.float64(0.0475551186375389)

# %% [markdown]
# ### X and y

# %%
X = data.drop('y',axis = 1)
y = data['y']

# %%
X.head(2)
# Out:
#    age  job  marital  education  default   balance  housing  loan  contact  \
# 0   58    4        1          2        0  6.803863        1     0        2
# 1   44    9        2          1        0  2.320596        1     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome
# 0    5      8       261         1     -1         0         3
# 1    5      8       151         1     -1         0         3

# %%
y.head(2)
# Out:
# 0    0
# 1    0
# Name: y, dtype: int64

# %%
X.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %% [markdown]
# ###  Find Best Random_state Number.

# %%
Train = []
Test = []
CV = []

for i in range(0,101):
    from sklearn.model_selection import train_test_split
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state= i)
    
    from sklearn.linear_model import LogisticRegression
    log_reg =LogisticRegression()
    log_reg.fit(X_train,y_train)
    
    ypred_train =log_reg.predict(X_train)
    ypred_test= log_reg.predict(X_test)
    
    from sklearn.metrics import accuracy_score
    Train.append(accuracy_score(y_train,ypred_train))
    Test.append(accuracy_score(y_test,ypred_test))
    
    from sklearn.model_selection import cross_val_score
    CV.append(cross_val_score(log_reg,X_train,y_train,cv=5,scoring="accuracy").mean())    
    
    
em =pd.DataFrame({"Train":Train, "Test":Test , "CV": CV})
gm = em[(abs(em['Train']-em['Test'])<=0.05) & (abs(em["Test"]-em["CV"])<=0.05)] 
rs = gm[gm["CV"]==gm["CV"].max()].index.to_list()[0]
print("Best Random State Number:",rs)

# %% [markdown]
# ### train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 17)

# %%
X_train.head()

# %%
X_test.head()

# %%
y_train.head()

# %%
y_test.head()

# %% [markdown]
# #### Decision Tree Classifier with default Hyperparameters
# * Modelling

# %%
from sklearn.tree import DecisionTreeClassifier
dt_default = DecisionTreeClassifier()
dt_default.fit(X_train,y_train)

# prediction
pred_train = dt_default.predict(X_train)
pred_test  = dt_default.predict(X_test)

# Evalution
from sklearn.metrics import accuracy_score
print("Train Accuracy :",accuracy_score(pred_train,y_train))
print("Test Accuracy :",accuracy_score(pred_test,y_test))

from sklearn.model_selection import cross_val_score
print("Cross_Validation_score :",cross_val_score(dt_default,X,y,cv=5).mean())

# %% [markdown]
# #### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# model
estimator = DecisionTreeClassifier(random_state=17)

# Parameters
param_grid ={'criterion':["gini","entropy"],
            "max_depth":list(range(1,16))}

grid =GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)

grid.fit(X_train,y_train)

grid.best_params_

# %%
grid.best_estimator_.feature_importances_

# %%
# Get the number of features the model is using
n_features = len(grid.best_estimator_.feature_importances_)

# Make sure the number of features matches
feats = pd.DataFrame(
    data=grid.best_estimator_.feature_importances_,
    index=X.columns[:n_features],  # Use only the relevant columns
    columns=["Feature Importance"]
)

# Filter important features
feats_imp = feats[feats["Feature Importance"] > 0]
important_features_list = feats_imp.index.to_list()

# %%
important_features_list

# %% [markdown]
# #### Final Model of Decision Tree Classifier

# %%
# input with important features

X_imp = X[important_features_list]

# train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_imp,y,test_size=0.2,random_state=17)

# model with best hyperparameters 
final_dt_model =DecisionTreeClassifier(criterion = 'gini', max_depth = 5,random_state=17)
final_dt_model.fit(X_train,y_train)

# prediction
ypred_train = final_dt_model.predict(X_train)
ypred_test  = final_dt_model.predict(X_test)

# Evalution
print("Train Accuracy :",accuracy_score(ypred_train,y_train))
print("Cross Validation Score :",cross_val_score(final_dt_model,X_imp,y,cv=5).mean())
print("Test Accuracy :",accuracy_score(ypred_test,y_test))
